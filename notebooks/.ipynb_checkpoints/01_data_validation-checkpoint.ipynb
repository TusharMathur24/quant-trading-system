# %% [markdown]
# # Quantitative Trading Strategy Development
# ## **Step 01 — Data Validation**
#
# **Objective:**
# Validate the raw market datasets before cleaning and feature engineering.
#
# This step ensures:
# - files are readable
# - data loads correctly
# - row counts are consistent
# - no structural issues exist

# %% [markdown]
# ## Project Context
#
# This notebook is part of a multi-stage quantitative trading pipeline:
#
# 1. Data Validation
# 2. Data Cleaning
# 3. Data Merging
# 4. Feature Engineering
# 5. Regime Detection
# 6. Strategy Backtesting
# 7. Performance Evaluation
#
# In this step, we focus only on **verifying raw input data integrity**.

# %%
import os
import sys

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development

# %% [markdown]
# ## 📥 Loading Raw Market Data
#
# The following datasets are used:
#
# | Dataset | Description |
# |------|------|
# | NIFTY Spot | Index price data |
# | NIFTY Futures | Futures contract prices |
# | NIFTY Options | Options chain data |
#
# We load the files to confirm:
# - file availability
# - readable CSV structure
# - successful parsing

# %%
from src.data_io import load_csv

# %%
spot = load_csv('data/raw/nifty_spot_5min.csv')
fut = load_csv('data/raw/nifty_futures_raw.csv')
opt = load_csv('data/raw/nifty_options_raw.csv')
# Out:
# Loaded 126 rows from c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development\data/raw/nifty_spot_5min.csv
# Loaded 5040 rows from c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development\data/raw/nifty_futures_raw.csv
# Loaded 269426 rows from c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development\data/raw/nifty_options_raw.csv

# %% [markdown]
# ## Validation Status
#
# All raw datasets have been successfully validated.
#
# **Next Step → Data Cleaning**
#
# The validated data will now be passed to the cleaning pipeline to:
# - fix datatypes
# - handle missing values
# - standardize column names

# %%
print('All raw files validated.')
# Out:
# All raw files validated.
