# %% [markdown]
# # Quantitative Trading Strategy Development
# ## **Step 02 — Data Cleaning**
#
# **Objective:**
# Clean and standardize raw market datasets to prepare them for merging
# and feature engineering.
#
# This step ensures:
# - consistent column names
# - correct data types
# - removal of invalid rows
# - standardized timestamps

# %% [markdown]
# ## Pipeline Context
#
# This notebook follows the data validation stage and prepares clean,
# structured datasets for downstream modeling.
#
# Pipeline flow:
#
# 1. Data Validation ✅
# 2. **Data Cleaning ← current step**
# 3. Data Merging
# 4. Feature Engineering
# 5. Regime Detection
# 6. Strategy Backtesting

# %%
import os
import sys

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development

# %%
from src.data_io import load_csv, save_csv
from src.cleaning import (
    clean_spot_data,
    clean_futures_data,
    clean_options_data
)

# %%
spot_raw = load_csv('data/raw/nifty_spot_5min.csv')
opt_raw = load_csv('data/raw/nifty_options_raw.csv')
fut_raw = load_csv('data/raw/nifty_futures_raw.csv')
# Out:
# Loaded 126 rows from c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development\data/raw/nifty_spot_5min.csv
# Loaded 269426 rows from c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development\data/raw/nifty_options_raw.csv
# Loaded 5040 rows from c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development\data/raw/nifty_futures_raw.csv

# %%
spot_clean = clean_spot_data(spot_raw)
fut_clean  = clean_futures_data(fut_raw)
opt_clean  = clean_options_data(opt_raw)
# Out:
#   > Cleaning Spot Data...
#   > Cleaning Futures Data...
#   > Cleaning Options Data...

# %%
save_csv(spot_clean, 'data/processed/nifty_spot_clean.csv')
save_csv(fut_clean, 'data/processed/nifty_futures_clean.csv')
save_csv(opt_clean, 'data/processed/nifty_options_clean.csv')
# Out:
# Saved file: c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development\data/processed/nifty_spot_clean.csv
# Saved file: c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development\data/processed/nifty_futures_clean.csv
# Saved file: c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development\data/processed/nifty_options_clean.csv
