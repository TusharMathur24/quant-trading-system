# %% [markdown]
# # Quantitative Trading Strategy Development
# ## **Step 04 — Feature Engineering**
#
# **Objective:**
# Generate informative numerical features from raw market data
# to support regime detection and trading strategy modeling.

# %% [markdown]
# ## Pipeline Context
#
# This notebook follows the data merging stage.
#
# Pipeline sequence:
#
# 1. Data Validation ✅
# 2. Data Cleaning ✅
# 3. Data Merging ✅
# 4. **Feature Engineering ← current step**
# 5. Regime Detection
# 6. Strategy Backtesting

# %%
import os
import sys

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development

# %%
from src.data_io import load_csv, save_csv
from src.features import add_technical_indicators, add_derived_features
from src.greeks import add_greeks

# %% [markdown]
# ## Loading Merged Market Dataset
#
# The merged dataset generated in the previous step is used as the base
# input for feature generation.

# %%
df = load_csv('data/processed/nifty_merged_5min.csv')
# Out:
# Loaded 126 rows from c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development\data/processed/nifty_merged_5min.csv

# %% [markdown]
# ## Technical Indicators
#
# Technical indicators capture market momentum, trend, and volatility.
#
# Examples include:
# - moving averages
# - RSI
# - volatility measures
# - price-based momentum indicators

# %%
df = add_technical_indicators(df)

# %% [markdown]
# ## Options Greeks
#
# Options Greeks quantify sensitivity of option prices to market variables.
#
# When option strike information is unavailable, Greek computation is
# safely skipped to avoid pipeline failure.

# %%
df = add_greeks(df)

# %% [markdown]
# ## Derived Features
#
# Derived features are constructed to enhance model interpretability,
# including:
#
# - return-based features
# - lagged variables
# - rolling statistics

# %%
df = add_derived_features(df)

# %% [markdown]
# ## Save Feature Dataset
# The final feature-enriched dataset is saved for use in regime detection and strategy modeling.

# %%
save_csv(df, 'data/processed/nifty_features_5min.csv')
# Out:
# Saved file: c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development\data/processed/nifty_features_5min.csv
