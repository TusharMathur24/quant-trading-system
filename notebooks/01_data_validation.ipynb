# %% [markdown]
# # Quantitative Trading Strategy Development
# ## Step 01 — Data Validation
#
# Objective:
# Verify the existence, readability, and structural integrity of raw
# market datasets before initiating the data processing pipeline.

# %% [markdown]
# ## Pipeline Context
#
# This notebook represents the first stage of the quantitative trading
# pipeline.
#
# Pipeline sequence:
#
# 1. Data Validation (current step)
# 2. Data Cleaning
# 3. Data Merging
# 4. Feature Engineering
# 5. Regime Detection
# 6. Strategy Backtesting
# 7. Machine Learning Enhancement
# 8. Outlier Analysis

# %%
import os
import sys

PROJECT_ROOT = os.path.abspath(os.path.join(".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %%
from src.data_io import load_csv

# %% [markdown]
# ## Purpose of Data Validation
#
# Data validation is performed to confirm:
#
# - raw data files exist
# - file paths are correctly configured
# - CSV files can be read without errors
# - dataset dimensions are reasonable
#
# No transformations are applied at this stage.

# %% [markdown]
# ## Loading Raw Market Data
#
# The following raw datasets are loaded from the `data/raw` directory:
#
# - NIFTY spot price data
# - NIFTY futures contract data
# - NIFTY options chain data

# %%
spot = load_csv('data/raw/nifty_spot_5min.csv')
fut = load_csv('data/raw/nifty_futures_raw.csv')
opt = load_csv('data/raw/nifty_options_raw.csv')
# Out:
# Loaded 126 rows from c:\Users\Tushar Mathur\Downloads\Quantitative_Trading_Strategy_Development\Quantitative_Trading_Strategy_Development\data/raw/nifty_spot_5min.csv

# %% [markdown]
# ## Validation Confirmation
#
# Successful loading of all datasets confirms that the raw data is
# available and structurally sound.
#
# This completes the data validation step and enables progression to
# data cleaning.

# %%
print('All raw files validated.')
# Out:
# All raw files validated.
